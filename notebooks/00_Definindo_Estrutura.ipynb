# %% [markdown]
# #1.0 Definição da Estrutura (Catalog e Schema)

# %%
# %sql
USE CATALOG workspace_ecommerce;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS silver;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gold;

# %% [markdown]
# #2.0 Criação do Volume (Staging Area)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS bronze.staging_zone_olist;

# %% [markdown]
# #3.0 Criando Volume Reports

# %%
# %sql
CREATE VOLUME IF NOT EXISTS bronze.reports;
